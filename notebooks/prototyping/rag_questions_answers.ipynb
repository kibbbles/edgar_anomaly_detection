# %% [markdown]
# # RAG Questions & Answers - Temporary Testing
#
# **Purpose:** Track questions and answers from RAG system during prototyping phase
#
# **Current Dataset:** 3 filings only (temporary test set)
#
# **Note:** This is a temporary notebook. A comprehensive evaluation notebook will be created after embedding all of 2024.
#
# ---

# %% [markdown]
# ## Test Setup
#
# **Filings in Current Database:**
# - Tesla 10-K (2024-01-29) - FY2023
# - Microsoft 10-Q (2024-01-30) - Q2 FY2024
# - Apple 10-Q (2024-02-02) - Q1 FY2024

# %% [markdown]
# ---
#
# ## Question 1: Tesla Total Revenue FY2023
#
# **Question:** What was Tesla's total revenue in fiscal year 2023?
#
# **Expected Answer:** $96,773 million or $96.8 billion
#
# **Source:** 20240129_10-K_edgar_data_1318605_0001628280-24-002390.json
#
# **RAG Answer:**
#
# *(Paste answer here)*
#
# **Retrieved Chunks:**
#
# *(Paste relevant chunks here)*
#
# **Evaluation:**
# - [ ] Correct
# - [ ] Partially correct
# - [ ] Incorrect
#
# **Notes:**
#
# ---

# %% [markdown]
# ## Question 2: Tesla Vehicle Production 2023
#
# **Question:** How many consumer vehicles did Tesla produce in 2023?
#
# **Expected Answer:** 1,845,985 vehicles
#
# **Source:** 20240129_10-K_edgar_data_1318605_0001628280-24-002390.json
#
# **RAG Answer:**
#
# *(Paste answer here)*
#
# **Retrieved Chunks:**
#
# *(Paste relevant chunks here)*
#
# **Evaluation:**
# - [ ] Correct
# - [ ] Partially correct
# - [ ] Incorrect
#
# **Notes:**
#
# ---

# %% [markdown]
# ## Question 3: Microsoft Cloud Revenue Q2 FY24
#
# **Question:** What was Microsoft's Intelligent Cloud segment revenue for the three months ended December 31, 2023?
#
# **Expected Answer:** $25,881 million or $25.9 billion
#
# **Source:** 20240130_10-Q_edgar_data_789019_0000950170-24-008814.json
#
# **RAG Answer:**
#
# *(Paste answer here)*
#
# **Retrieved Chunks:**
#
# *(Paste relevant chunks here)*
#
# **Evaluation:**
# - [ ] Correct
# - [ ] Partially correct
# - [ ] Incorrect
#
# **Notes:**
#
# ---

# %% [markdown]
# ## Question 4: Apple iPhone Revenue Q1 FY24
#
# **Question:** What was Apple's iPhone net sales for the quarter ended December 30, 2023?
#
# **Expected Answer:** $69,700 million or $69.7 billion
#
# **Source:** 20240202_10-Q_edgar_data_320193_0000320193-24-000006.json
#
# **RAG Answer:**
#
# *(Paste answer here)*
#
# **Retrieved Chunks:**
#
# *(Paste relevant chunks here)*
#
# **Evaluation:**
# - [ ] Correct
# - [ ] Partially correct
# - [ ] Incorrect
#
# **Notes:**
#
# ---

# %% [markdown]
# ## Additional Questions
#
# *(Add more questions as needed)*

# %% [markdown]
# ---
#
# ## Summary
#
# **Total Questions:**
#
# **Correct Answers:**
#
# **Partially Correct:**
#
# **Incorrect Answers:**
#
# **Accuracy Rate:**
